# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp
# 0                              Braund, Mr. Owen Harris    male  22.0      1  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df = df.sample(frac = 1)
df
# Out:
#      PassengerId  Survived  Pclass
# 383          384         1       1  \
# 565          566         0       3
# 740          741         1       1
# 308          309         0       2
# 769          770         0       3
# ..           ...       ...     ...
# 63            64         0       3
# 245          246         0       1
# 796          797         1       1
# 411          412         0       3
# 618          619         1       2
#
#                                                   Name     Sex   Age  SibSp
# 383  Holverson, Mrs. Alexander Oskar (Mary Aline To...  female  35.0      1  \
# 565                               Davies, Mr. Alfred J    male  24.0      2
# 740                        Hawksford, Mr. Walter James    male   NaN      0
# 308                                Abelson, Mr. Samuel    male  30.0      1
# 769                   Gronnestad, Mr. Daniel Danielsen    male  32.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df_200 = df.sample(n = 200) # случайный выбор строк
df_200
# Out:
#      PassengerId  Survived  Pclass
# 61            62         1       1  \
# 826          827         0       3
# 62            63         0       1
# 38            39         0       3
# 890          891         0       3
# ..           ...       ...     ...
# 610          611         0       3
# 484          485         1       1
# 405          406         0       2
# 317          318         0       2
# 747          748         1       2
#
#                                                   Name     Sex   Age  SibSp
# 61                                 Icard, Miss. Amelie  female  38.0      0  \
# 826                                       Lam, Mr. Len    male   NaN      0
# 62                         Harris, Mr. Henry Birkhardt    male  45.0      1
# 38                  Vander Planke, Miss. Augusta Maria  female  18.0      2
# 890                                Dooley, Mr. Patrick    male  32.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df_200['Age'].hist()
# Out:
# <AxesSubplot: >

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import random
import seaborn as sns

nx = np.random.normal(24, 10, 200) #mu, sigma,number of values
plt.hist(nx)
plt.show()

# %%
# проверить оценку мат ожидания на несмещенность и состоятельность (колонка Age)
# проверить оценку дисперсии на несмещенность и состоятельность
# несмещенность  - сделать N подвыборок одинакового размера, рассчитать мат ожидание для каждой,
# рассчитать среднее среди всех матожиданий - должна получиться оценка для генеральной совокупности
# состоятельность - рассчитывать параметр со все увеличивающимся количеством точек. 
# Оценка должна приближаться к основной рассчитанной оценке. Построить график приближения оценки с ростом числа N.
