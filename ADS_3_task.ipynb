# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp
# 0                              Braund, Mr. Owen Harris    male  22.0      1  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df_200 = df.sample(n = 200) # случайный выбор строк
df_200
# Out:
#      PassengerId  Survived  Pclass
# 61            62         1       1  \
# 826          827         0       3
# 62            63         0       1
# 38            39         0       3
# 890          891         0       3
# ..           ...       ...     ...
# 610          611         0       3
# 484          485         1       1
# 405          406         0       2
# 317          318         0       2
# 747          748         1       2
#
#                                                   Name     Sex   Age  SibSp
# 61                                 Icard, Miss. Amelie  female  38.0      0  \
# 826                                       Lam, Mr. Len    male   NaN      0
# 62                         Harris, Mr. Henry Birkhardt    male  45.0      1
# 38                  Vander Planke, Miss. Augusta Maria  female  18.0      2
# 890                                Dooley, Mr. Patrick    male  32.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# Метод моментов
#
# Начальные моменты
# ![image.png](attachment:image.png)
# Начальный момент порядка k, где x_i - событие, p_i - вероятность этого события
#
# Центральные моменты
# ![image-2.png](attachment:image-2.png)
#
# Рассчет параметров распределения
# ![image-3.png](attachment:image-3.png)
#
# Т.е. рассчитав начальный момент первого порядка, центральный момент второго порядка, можно сформировать систему уравнений для мат ожидания и дисперсии. Подставив параметры распределения, получим оценки параметров.
#  - Состоятельные оценки.
#  - легко рассчитать.
#  Не всегда эффективны.

# %%
# Бернулли.
# Параметры распределения Бернулли для колонки "Sex". 
# Во сколько раз чаще можно встретить женщину на корабле?

# %%
# Биномиальное.
# Для n = 50 оценить параметры распределения Биномиального, колонка "Sex"
# Построить графики распределения вероятностей для реальных полученных значений и для статистики,
# полученной на 100 подвыборках исходных данных

# %%
# Геометрическое
# из предположения, что индекс - временной шаг,
# определить параметры геометрического распределения, а именно:
# насколько вероятно встретить "выжившего" (survived) человека через 0,1,2,3 человек..., если рассматривать 
# их "проходящими мимо тебя" в последовательности, указанной в таблице.
# построить графики для реальных значений распределения вероятностей, и полученного распределения по оценкам.

# %%
# Гауссов (Нормальный) закон.
# из предположения, что возраст (столбец Age) распределен по нормальном закону, оценить параметры распределения для столбца
# Age.
# Построить графики для оцененного распределения, и реальное распределения частот встречаемости.

# %%
# Парето.
# На основании информации о распределении Fare - оплаты за билет, выяснить, 
# какой процент человек внес 80% оплаты за проезд.
# ex. упорядочить столбец по убыванию, отсечь P% записей, в которых наблюдается
